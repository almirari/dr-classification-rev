# %%
# %run "D:/UNI/TUGAS-AKHIR/code/dr-classification-rev/05_results/eval_baseline.py"
# Out:
# ...
#   01_baseline — Standalone Model Evaluation (CE / CORAL / CORN / Niu)
# ...
#   Project root : D:\UNI\TUGAS-AKHIR\code\dr-classification-rev
#   Results dir  : D:\UNI\TUGAS-AKHIR\code\dr-classification-rev\05_results
#   Device       : cpu
#
# [Dataset]
#   Extracting dataset.zip ...
#   Extracted → D:\UNI\TUGAS-AKHIR\code\dr-classification-rev\_dataset_extracted
#   Test samples : 367
#
#
# ...
#   Baseline — MobileNetV3-Small (Cross-Entropy)
# ...
#
#   Seed 33 — s1_seed33_best.pth
#   Training best val QWK: 0.8959
#   Evaluating ...
#     batch 12/12
#   QWK=0.8484 | Acc=79.84% | MAE=0.2834 | RMSE=0.6886 | Params=1.52M | Size=5.96MB | Lat=29.595ms | Mem=nanMB
#
#   Seed 81 — s1_seed81_best.pth
#   Training best val QWK: 0.9003
#   Evaluating ...
#     batch 12/12
#   QWK=0.8307 | Acc=78.75% | MAE=0.3106 | RMSE=0.7419 | Params=1.52M | Size=5.96MB | Lat=7.118ms | Mem=nanMB
#
#   Seed 5 — s1_seed5_best.pth
#   Training best val QWK: 0.8919
#   Evaluating ...
#     batch 12/12
# ...

# %%
# %run "D:/UNI/TUGAS-AKHIR/code/dr-classification-rev/05_results/eval_singlekd.py"
# Out:
# ...
#   03_kd_single — Student + Teacher Evaluation
# ...
#   Project root : D:\UNI\TUGAS-AKHIR\code\dr-classification-rev
#   Results dir  : D:\UNI\TUGAS-AKHIR\code\dr-classification-rev\05_results
#   Device       : cpu
#
# [Dataset]
#   Dataset already extracted → D:\UNI\TUGAS-AKHIR\code\dr-classification-rev\_dataset_extracted
#   Test samples : 367
#
#
# ############################################################################
#   STUDENT MODELS
# ############################################################################
#
#
# ...
#   Single-Teacher KD — CE  (ResNet-50-CE → MobileNetV3-Small)
# ...
#
#   Seed 33 — seed33_best.pth
#   Head : CE  |  Training best val QWK: 0.9091
#   Evaluating ...
#     batch 12/12
#   QWK=0.8744 | Acc=81.20% | MAE=0.2480 | RMSE=0.6242 | Params=1.52M | Size=5.94MB | Lat=7.266ms | Mem=nanMB
#
#   Seed 81 — seed81_best.pth
#   Head : CE  |  Training best val QWK: 0.9036
#   Evaluating ...
#     batch 12/12
# ...

# %%
# %run "D:/UNI/TUGAS-AKHIR/code/dr-classification-rev/05_results/eval_multikd.py"
# Out:
# ...
#   04_kd_multi — Student + Teacher Evaluation
# ...
#   Project root : D:\UNI\TUGAS-AKHIR\code\dr-classification-rev
#   Results dir  : D:\UNI\TUGAS-AKHIR\code\dr-classification-rev\05_results
#   Device       : cpu
#
# [Dataset]
#   Dataset already extracted → D:\UNI\TUGAS-AKHIR\code\dr-classification-rev\_dataset_extracted
#   Test samples : 367
#
#
# ############################################################################
#   STUDENT MODELS
# ############################################################################
#
#
# ...
#   Multi-Teacher KD — Nominal CE  (ResNet-50-CE + EffNetB3-CE → MobileNetV3-Small)
# ...
#
#   Seed 33 — kd_seed33_best.pth
#   Head : CE  |  Training best val QWK: 0.8940
#   Evaluating ...
#     batch 12/12
#   QWK=0.8386 | Acc=78.47% | MAE=0.3025 | RMSE=0.7176 | Params=1.52M | Size=5.94MB | Lat=7.072ms | Mem=nanMB
#
#   Seed 81 — kd_seed81_best.pth
#   Head : CE  |  Training best val QWK: 0.8941
#   Evaluating ...
#     batch 12/12
# ...
